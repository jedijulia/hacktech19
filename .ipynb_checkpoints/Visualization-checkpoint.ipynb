# %% [markdown]
# # Word Cloud

# %%
from nltk import word_tokenize, WordNetLemmatizer
from nltk.corpus import stopwords

def preprocess(text):
    lemmatizer = WordNetLemmatizer()
    stop_words = stopwords.words('english')
    words = [lemmatizer.lemmatize(word.lower()) for word in word_tokenize(text)]
    return ' '.join(words)

import csv

filenames = ['good.csv', 'bag_dataset.csv', 'bottle_dataset.csv']

good_data = []
bad_data = []
for filename in filenames:
    with open(filename, 'r') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        fields = ['material']
        # combine text from fields
        for row in csv_reader:
            text = ''
            for field in fields:
                text += row[field]
            text = preprocess(text.decode('utf8'))
            if row['target'] == '1':
                good_data.append(text.encode("utf-8"))
            else:
                print text
                bad_data.append(text.encode("utf-8"))

with open('good_data.txt', 'w') as good_file:
    for good in good_data:
        good_file.write(good)
        
with open('bad_data.txt', 'w') as bad_file:
    for bad in bad_data:
        bad_file.write(bad)
# Out:
# 100 % cotton
# 100 % cotton
# stainless steel
# stainless steel , silicone
# 100 % cotton
#
# stainless steel body , plastic cap .
# 100 % natural cotton
# 100 % natural cotton
# palm leaf , leather
# 100 % natural cotton
# food grade recycled plastic ( polypropylene # 5 ) , bpa free , bps free ( a popular bpa replacement with the similar concern ) , phthalate free
# food grade recycled plastic ( polypropylene # 5 ) , bpa free , bps free ( a popular bpa replacement with the similar concern ) , phthalate free
# bpa-free , glass
# cotton
# cotton
# organic un-dyed french terry cotton
# bpa-free , stainless steel
# bpa-free , glass
# this 12oz cup is made of fully tempered soda lime glass , the keepcup brew cork edition feature a natural cork band . made in portugal using waste product from the wine cork manufacture , the band is beautiful to hold . over time it ’ s patina will tell the story of your use . lid is made of bpa and bps free polyproplyene # 7 and ldpe # 4 .
# stainless steel lid with silicone ring
# stainless steel
# stainless steel , silicone
# stainless steel cap with silicone ring
# organic cotton
# organic cotton
# stainless steel body , plastic cap
# stainless steel body , bamboo and steel cap
# pure platinum silicone - hypoallergenic , bpa and bps free
# pure platinum silicone - hypoallergenic , bpa and bps free
# pure platinum silicone - hypoallergenic , bpa and bps free
# bottle , stainless steel . cap , plastic
# glass bottle with plastic spray top
# organic cotton
# unbleached certified organic cotton . the insulation is 100 % wool and the dye are made of natural and non-toxic vegetable dye
# food-grade silicone + 18/8 stainless steel
# 75 % jute , 25 % cotton
# 18/8 stainless steel body , bpa-free polypropylene # 5 with silicone gasket lid , 18/8 stainless steel straw with silicone tip .
# gmo free starch , biodegradable polymer and other renewable resource
